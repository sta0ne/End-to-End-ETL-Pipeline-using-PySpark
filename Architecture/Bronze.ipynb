# %%
df_bronze = spark.read.format('csv').option('Inferschema',True).option('header',True).load('/Volumes/firstproject1/default/source/Sample - Superstore.csv')

# %%
df_bronze.display()

# %%
df_bronze.printSchema()

# %%
df_bronze.write \
    .mode("overwrite") \
    .parquet("/Volumes/firstproject1/default/bronze/superstore")
